# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel("customer_retention_dataset.xlsx")

# %%
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
data.shape
# Out:
# (269, 71)

# %% [markdown]
# There are 269 rows and 71 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# Let us look into each column seperately to get a good understanding.

# %%
data['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# There are more female who tend to shop more.

# %%
data['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
sns.countplot(data['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
sns.countplot(data['2 How old are you? '], hue=data['1Gender of respondent'] )
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# ## INITIAL ASSUMPTIONS AND THOUGHTS: <br>
# 1) Most of the customer are Females between 21-30 Years. However, Customer more than 20 years tend to use online shopping more. This may be due to convenience and ease the online shopping provides.<br>
# 2) On top of that, shopping online we can browse through the categories multiple times and can be done on any part of the day. There are multiple other advantages as well.<br>
# 3) **This saves time and looking at the above plot, I can say that cusomers above 20 seems to work (for a company or does business). So, customers will be looking for a hassle free experience**.<br>
# 4) Online shopping provides home deliveries, that is a convenience.<br> Multiple brands or multiple website are at reach. SO **CONVENIENCE, SHOPPING EXPERIENCE, EASE, BRAND VALUE, PACKAGING (When the order is delivered), CUSTOMER SERVICE OR AFTER SALES SUPPORT, TRUST, CUSTOMER INTERFACE(UI ATTRACTIVENESS) and PRODUCT ITSELF**. I feel these aspects may be some of the main things that would contribute to an amazing shopping experience.<br>
#
# ## HOW AND WHAT TO FOCUS AND IMPROVE:<br>
# However, how can we improve this online experience? How and what shall or should be our main agenda or our main focus to attract customer and hold them?<br>
# 1) **It is very important to retain existing customers then attracting new customer**. As attracting new customer involves advertisements, promotions and multiple marketing techniques which may charge our company a fortune.
# 2) Being said that, we would need to have a good plan on promoting our business or products. Many effective and economical ways can be planned and executed depending upon the target customer we want to sell or the product is meant for and the time and method it needs to be advertised.<br>
# 3) This would require a very good understaning about the customer.<br>
# 4) **THE MAIN AIM OF THIS PROJECT IS TO RETAIN CUSTOMERS, SO WE WILL TRY TO ANALYSE IN THE VERY SIMPLEST FORM POSSIBLE AND EXTRACT AS MUCH AS INFORMATION FROM THE DATA TO MAKE SURE CUSTOMER WE SUCCED IN HOLDING THEIR TRUST AND BUSINESS WITH US (OUR COMPANY).**<br>
# Lets look into remaining data.

# %%
data['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
sns.countplot(data['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
plt.xticks(rotation=45)
sns.countplot(data['3 Which city do you shop online from?'], hue=data['1Gender of respondent'] )
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# Most of the customers are from Delhi and around Delhi (Noida and Greater Noida). I can say that City in this case is important, however, not that much.

# %%
plt.figure(figsize=(16,7))
plt.xticks(rotation=45)
sns.countplot(data['3 Which city do you shop online from?'], hue=data['2 How old are you? '] )
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# This plot gives us customer ages acording to the cities.

# %%
data['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['4 What is the Pin Code of where you shop online from?'], hue=data['1Gender of respondent'] )
# Out:
# <AxesSubplot:xlabel='4 What is the Pin Code of where you shop online from?', ylabel='count'>

# %%
data['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['5 Since How Long You are Shopping Online ?'], hue=data['1Gender of respondent'] )
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# There are more customers with above 4 years online shopping history. This proves that customers enjoy online shopping and we need more effort to retain them.

# %%
data['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['6 How many times you have made an online purchase in the past 1 year?'], hue=data['1Gender of respondent'] )
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# However, this columns slightly contradicts the above assumption we made with number of years customers using online shopping. There is a huge number of customer numbers who shopped less than 10 times past year. Let's move forward and look at other features.

# %%
data['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['7 How do you access the internet while shopping on-line?'], hue = data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# The categories in this column have two same names "Mobile Internet". So the basic focus should be on developing an easy and attractive UI for Mobile platform. As out of 269, 189 entries or customer use Mobile data.

# %%
data['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['8 Which device do you use to access the online shopping?'], hue = data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# This plot also suggests that most of the customers use Smartphones or Tablets. Yes, there are customers with Laptop and Desktop. However, this suggest that we focus more on smartphones and Tablets.

# %%
data['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '], hue = data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %% [markdown]
# Most of the screen resolutions are more than 5.5 inches.

# %%
data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '])
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '], hue = data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %% [markdown]
# Most of the operating systems are Window/Windows Mobile.

# %%
data['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['11 What browser do you run on your device to access the website?\t\t\t                                                          '])
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %% [markdown]
# Most Customers use Google Chrome. So we would need to make sure that the UI with Google Chrome should be very smooth and easy.

# %%
data['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [markdown]
# Search Engine channel has most votes, that means that customers have a liking for the brand or service. This suggest that company or brand need to build a good realtion of trust with the customers.

# %%
data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
# Out:
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '], hue=data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %%
data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '], hue=data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %% [markdown]
# So customer explores all the options before placing an order. That is more than 15 minutes.

# %%
data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '], hue=data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %% [markdown]
# Most customers like to use Cards to place an order. However, more number of payment methods will really attract more number of customers to place an order.

# %%
data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '], hue=data['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ', ylabel='count'>

# %% [markdown]
# Most of the customers abandon the cart. This doesn't really point at our problem at the moment.

# %%
data['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
plt.figure(figsize=(18,7))
plt.xticks(rotation=45)
sns.countplot(data['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ', ylabel='count'>

# %% [markdown]
# This plot tells that better customer abandon the cart due to better alternatives and promo code applications denails. So a very competetive pricing strategy is to be applied.

# %%
data['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
data['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
data['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
data['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
data['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
data['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
data['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
figure, axes = plt.subplots(3,3, figsize=(26,14))
sns.countplot(ax=axes[0,0], data=data, x= '18 The content on the website must be easy to read and understand')
sns.countplot(ax=axes[0,1], data=data, x= '19 Information on similar product to the one highlighted  is important for product comparison')
sns.countplot(ax=axes[0,2], data=data, x= '20 Complete information on listed seller and product being offered is important for purchase decision.')
sns.countplot(ax=axes[1,0], data=data, x= '21 All relevant information on listed products must be stated clearly')
sns.countplot(ax=axes[1,1], data=data, x= '22 Ease of navigation in website')
sns.countplot(ax=axes[1,2], data=data, x= '23 Loading and processing speed')
sns.countplot(ax=axes[2,0], data=data, x= '24 User friendly Interface of the website')
sns.countplot(ax=axes[2,1], data=data, x= '25 Convenient Payment methods')
sns.countplot(ax=axes[2,2], data=data, x= '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time')
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %% [markdown]
# ## Observations:<br>
# 1) Content should be easy to read and understand. This is what we already assumed, the plot proved this true. <br>
# 2) Information on similar product to the one highlighted is very important. This is also assumed with plot on how much time customer waits to place an order. That was 15 minutes.<br>
# 3) Clear information about seller and product is very much necessary for customer retention or placing an order.<br>
# 4) All relevant information on listed product must be clearly stated. This is already assumed.<br>
# 5) Ease of navigation. This was also assumed and seems important.<br>
# 6) Loading and processing speed has most strongly agree votes. This accounts to the ease and time saving of the customer. <br>
# 7) User friendly  interface is very importand and we talked about this as well.<br>
# 8) Payments methods. the more payment method the more convenient. This improves and helps us retain customers.<br>
# 9) Trust. This would be very important and already talked about this aspect as well.

# %%
data['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
data['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
data['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
data['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
data['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
data['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
data['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
data['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
figure, axes = plt.subplots(3,3, figsize=(26,14))
sns.countplot(ax=axes[0,0], data=data, x= '27 Empathy (readiness to assist with queries) towards the customers')
sns.countplot(ax=axes[0,1], data=data, x= '28 Being able to guarantee the privacy of the customer')
sns.countplot(ax=axes[0,2], data=data, x= '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)')
sns.countplot(ax=axes[1,0], data=data, x= '30 Online shopping gives monetary benefit and discounts')
sns.countplot(ax=axes[1,1], data=data, x= '31 Enjoyment is derived from shopping online')
sns.countplot(ax=axes[1,2], data=data, x= '32 Shopping online is convenient and flexible')
sns.countplot(ax=axes[2,0], data=data, x= '33 Return and replacement policy of the e-tailer is important for purchase decision')
sns.countplot(ax=axes[2,1], data=data, x= '34 Gaining access to loyalty programs is a benefit of shopping online')
sns.countplot(ax=axes[2,2], data=data, x= '35 Displaying quality Information on the website improves satisfaction of customers')
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %% [markdown]
# ## Observations:<br>
# 1) After sales service or customer service is very important. That's what this plot suggests.<br>
# 2) Privacy protection is very important and this add to the trust of the brand towards customers. <br>
# 3) Customer service again. An example would be Amazon, which provide a very good customer service.<br>
# 4) Promotions or membership benefits attracts and helps retain more customers. This is a very vital service or benefits that a company should provide to choose our customers over other competitors.<br>
# 5) All the other above plots showcase all the aspects already talked or assumed in this problem statement.

# %%
data['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
data['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
data['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
data['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
data['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
data['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
data['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
data['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
data['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
figure, axes = plt.subplots(3,3, figsize=(26,14))
sns.countplot(ax=axes[0,0], data=data, x= '36 User derive satisfaction while shopping on a good quality website or application')
sns.countplot(ax=axes[0,1], data=data, x= '37 Net Benefit derived from shopping online can lead to users satisfaction')
sns.countplot(ax=axes[0,2], data=data, x= '38 User satisfaction cannot exist without trust')
sns.countplot(ax=axes[1,0], data=data, x= '39 Offering a wide variety of listed product in several category')
sns.countplot(ax=axes[1,1], data=data, x= '40 Provision of complete and relevant product information')
sns.countplot(ax=axes[1,2], data=data, x= '41 Monetary savings')
sns.countplot(ax=axes[2,0], data=data, x= '42 The Convenience of patronizing the online retailer')
sns.countplot(ax=axes[2,1], data=data, x= '43 Shopping on the website gives you the sense of adventure')
sns.countplot(ax=axes[2,2], data=data, x= '44 Shopping on your preferred e-tailer enhances your social status')
# Out:
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %% [markdown]
# ## Observations:<br>
# All the above plots are selft explanatory and is straight forward. Looking at the data and plots, it is clear that this field is very competative and requires huge amount of effort to be on the top of the competetion. Our assumptions are on to the point and the above plots suggests us to maintain a seperate team for each of the aspects we discussed in this problem statement.

# %%
data['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %% [markdown]
# Looking at the value counts, the most shopped website is 1) Amazon.in, 2) Flipkart.com, 3) Paytm.com, 4) Snapdeal.com and 5) Myntra.com

# %% [markdown]
# So Amazon.in and Flipkart.com are the most trusted and liked websites in India.

# %%
data['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# Easy to use website or application would be Amazon.in, this also backs the website for being most trusted and liked website in India.

# %%
data['Visual appealing web-page layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
data['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
data['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
data['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
data['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
data['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
data['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
data['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
data['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Flipkart.com                                                    15
# Amazon.in, Paytm.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
data['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
data['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
data['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
data['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
data['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
data['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
data['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
data['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
data['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
data['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
data['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
data['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
data['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# ## Observations:<br>
# All these above value counts are practical data acquired from the customers and Amazon.in, Amazon.com clearly wins being the best website customer website. <br>

# %% [markdown]
# # Details or obsevations observed by this data set:<br>
# 1) Website or application should be easy to use.<br>
# 2) Visual appealing web-page layout should be appealing and easy to use (User friendly).<br>
# 3) Website should offer variety of products with all the relevant information on the products is essential.<br>
# 4) Reliability of the website or application is very important. This builds trust with the customer and this builds a sense of personalised attachment with the website or application.<br>
# 5) Quickness to complete purchase and several payment methods is very important. This increases convenience, saves time and encourages sale.<br>
# 6) Speedy order delivery and fulfilling promises made is essential. This makes business a brand. <br>
# 7) Next observation would be the DATA PRIVACY of the customer. DATA PROTECTION would be the most vital part of the business as there are seperate government policies to ensure security. Website or Application should ensure DATA PRIVACY and DATA PROTECTION.<br>
# 8) Next observation would be Customer Service or after sales services. Better and reliable service encourages sale and customer retention. This services is also a vital aspect of this business. This service also looks into returns and replacements. This is a convenience and encourages trust and sales.<br>
# 9) Website and application should load faster and easy to use. All the features, button etc.., should be easily reachable or visible.<br>
# 10) Next observation would be loyalty programm or benefits for each purchase is important. Promotions, referrals and benefits attracts customer and retains customers.<br>
# 11) Most famous and liked website in India would be "AMAZON.IN", "FLIPKART.COM" and "MYNTRA.COM". <br>
#
# These are the observations from this data set.
